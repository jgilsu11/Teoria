# %%
import pandas as pd

# %%
df_gastos= pd.read_csv("datos\DatosFinales\gastos.csv")
df_ingresos= pd.read_csv("datos\DatosFinales\ingresos.csv")

# %%
df_gastos["año"].unique()
# Out:
# array([2020, 2019, 2018, 2016, 2017, 2015, 2014, 2010, 2011, 2013, 2012])

# %%
len(df_gastos["ncodi"].unique())
# Out:
# 857

# %%
df_gastos
# Out:
#        año   ncodi  totalcompra  producfarma  materialsani  implantes  \
# 0     2020   113.0      1535894     344330.0        169443        0.0
# 1     2020   619.0      7884157     971762.0       1749006   493444.0
# 2     2020   163.0      5453290     126493.0       1412366   574127.0
# 3     2020   131.0       245802      72318.0         52506        0.0
# 4     2020   375.0       762218     114702.0        106844       60.0
# ...    ...     ...          ...          ...           ...        ...
# 8445  2012   970.0       271324       8510.0        166422        0.0
# 8446  2012  1019.0      1687968     126665.0         94290        0.0
# 8447  2012  1016.0      5418532     336983.0       1152639   145404.0
# 8448  2012  1047.0     15537164    5516672.0       5255744   565150.0
# 8449  2012   635.0     14508459    6275019.0       4311556   231481.0
#
#       restomateriasani  servcontratado  trabajocontratado  xrestocompras  ...  \
# 0             169443.0          1877.0           678201.0       342043.0  ...
# 1            1255562.0       3800207.0          1248674.0       114508.0  ...
# 2             838239.0       3217684.0           647852.0        48895.0  ...
# 3              52506.0          1114.0            24303.0        95561.0  ...
# 4             106784.0         14526.0           188463.0       337683.0  ...
# ...                ...             ...                ...            ...  ...
# 8445          166422.0             0.0            96392.0            0.0  ...
# 8446           94290.0       1080335.0           300411.0        86267.0  ...
# 8447         1007235.0       2739305.0          1126019.0        63586.0  ...
# 8448         4690594.0             0.0          3287539.0      1477209.0  ...
# 8449         4080075.0             0.0          3244840.0       677044.0  ...
#
#       xrestoserviexter  gastopersonal   sueldos  indemnizacion  segsocempresa  \
# 0             506018.0       26209836  19875799       349499.0        5984538
# 1            2635675.0        7083969   5203283       151380.0        1591074
# 2             882274.0        2890388   2180177         -402.0         663398
# 3             487053.0        1887375   1437421         9506.0         416398
# 4             192132.0        7764302   5838470            0.0        1837175
# ...                ...            ...       ...            ...            ...
# 8445           90752.0        1010376    796935            0.0         213441
# 8446           54771.0        2447989   1852771            0.0         590887
# 8447         1360669.0        2624854   2066623            0.0         545427
# 8448         4808689.0       43164526  34899381            0.0        8056716
# 8449         2108452.0       38113657  30888193            0.0        7040348
#
#       otrgassocial  dotaamortizacion  perdidadeterioro  xrestogasto  \
# 0              0.0          298707.0           -6504.0      50165.0
# 1         138232.0         2423752.0               0.0     312984.0
# 2          47215.0          202688.0          -54028.0     232471.0
# 3          24050.0           12084.0             240.0     132044.0
# 4          88657.0          184413.0           93708.0       1552.0
# ...            ...               ...               ...          ...
# 8445           0.0          104331.0               0.0      63796.0
# 8446        4331.0          132364.0               0.0          0.0
# 8447       12804.0           32691.0           99382.0     199998.0
# 8448      208429.0         3297451.0               0.0          0.0
# 8449      185116.0         1025569.0               0.0     150643.0
#
#       totcompragasto
# 0           28810972
# 1           20573925
# 2            9677715
# 3            2844476
# 4            9037657
# ...              ...
# 8445         1945741
# 8446         4493647
# 8447        10166669
# 8448        68948001
# 8449        56338842
#
# [8450 rows x 23 columns]

# %%
df_ingresos["año"].unique()
# Out:
# array([2013, 2014, 2015, 2012, 2017, 2010, 2019, 2021, 2020, 2018, 2011,
#        2016])

# %%
len(df_ingresos["ncodi"].unique())
# Out:
# 2424

# %%
df_ingresos.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_ingresos["tipo"].unique()
# Out:
# array(['Hospital', 'consulExter', 'CMA', 'hospDia', 'Urgencia', 'hospDom'],
#       dtype=object)

# %%
df_ingresos["ncodi"].str.replace(",",".")

# %%
df_ingresos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55326 entries, 0 to 55325
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               55326 non-null  int64
#  1   particulares             53952 non-null  float64
#  2   aseguradoras             55322 non-null  float64
#  3   aseguradoras_enfermedad  53952 non-null  float64
#  4   aseguradoreas_trafico    53859 non-null  float64
#  5   mutuas                   53942 non-null  float64
#  6   tipo                     55326 non-null  object
#  7   año                      55326 non-null  int64
#  8   ncodi                    55308 non-null  object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 3.8+ MB

# %%
df_ingresos.sample(10)
# Out:
#        Unnamed: 0  particulares  aseguradoras  aseguradoras_enfermedad  \
# 1087         1087           0.0           0.0                      0.0
# 26218       26218       36864.0      468061.0                  22349.0
# 26112       26112       26388.0       69076.0                  29765.0
# 37794       37794           0.0           0.0                      0.0
# 36923       36923     1043312.0    29005430.0               28760323.0
# 5080         5080       26972.0      293607.0                 173980.0
# 50086       50086           0.0           0.0                      0.0
# 45602       45602           0.0           0.0                      0.0
# 53596       53596         114.0           0.0                      0.0
# 6170         6170        4150.0           0.0                      0.0
#
#        aseguradoreas_trafico    mutuas         tipo   año   ncodi
# 1087                     0.0       0.0  consulExter  2013  266,00
# 26218               445712.0  134099.0     Urgencia  2010  918,00
# 26112                39311.0   58077.0     Urgencia  2010  993,00
# 37794                    0.0       0.0  consulExter  2020     883
# 36923               245107.0  251037.0     Hospital  2020     921
# 5080                119627.0   38715.0     Hospital  2014  846,00
# 50086                    0.0       0.0      hospDom  2011  302,00
# 45602                    0.0       0.0      hospDom  2018     174
# 53596                    0.0     457.0      hospDia  2016     849
# 6170                     0.0       0.0          CMA  2014  663,00
