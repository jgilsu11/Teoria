# %%
import asyncio

# %%
async def main():           #transforma esta funcion asincónica
    print("Hola mundo asincronico")

# %%
await main()
# Out:
# Hola mundo asincronico

# %% [markdown]
# para ver la diferencia con la programación secuencial

# %%
async def tarea1_di_hola():
    print("Iniciando la tarea 1")
    await asyncio.sleep(2) 
    print("Hola mundo asincronico")



async def tarea2_hacer_otra_cosa():
    print("Iniciando la tarea 2")
    await asyncio.sleep(1) 
    print("Terminando la tarea 2")


async def main2():                               #Te ejecuta las dos a la vez pero gracias al await .sleep sale una antes de la otra (el orden de salida se puede modificar modificando el tiempo del sleep)
    await asyncio.gather(tarea1_di_hola(), tarea2_hacer_otra_cosa())



await main2()
# Out:
# Iniciando la tarea 1
# Iniciando la tarea 2
# Terminando la tarea 2
# Hola mundo asincronico

# %% [markdown]
# Empiezan ambas a la vez pero la AZUL dependerá de cuando acabe la ROJA para mostrarla
# lo bueno es que mientras que la ROJA se ejecuta como la AZUL ya está lista aunque no se pueda mostrar, se puede usar para otras cosas mientras la ROJA termina.
#
# Se necesita que el proceso ROJO acabe para que nos devuelva la AZUL

# %% [markdown]
# ![WhatsApp Image 2024-10-17 at 10.36.25.jpeg](<attachment:WhatsApp Image 2024-10-17 at 10.36.25.jpeg>)

# %% [markdown]
# Más ejemplos: Pasta
